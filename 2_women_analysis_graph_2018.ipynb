# %% [markdown]
# # Study of women participation in higher education in 2018

# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import *

df_total = pd.read_csv("data/2018.csv",sep="|", dtype='unicode')

df = df_total.query('TP_SEXO == "1"')

df[:10]
# Out:
#    NU_ANO_CENSO CO_IES TP_CATEGORIA_ADMINISTRATIVA TP_ORGANIZACAO_ACADEMICA  \
# 0          2018    605                           3                        1
# 2          2018     14                           5                        1
# 3          2018   1113                           5                        2
# 5          2018   1365                           5                        2
# 6          2018    823                           5                        1
# 7          2018    221                           4                        1
# 10         2018   1735                           4                        2
# 12         2018     19                           5                        1
# 13         2018     15                           5                        1
# 14         2018    221                           4                        1
#
#    CO_CURSO CO_CURSO_POLO TP_TURNO TP_GRAU_ACADEMICO TP_MODALIDADE_ENSINO  \
# ...

# %% [markdown]
# ## How many women there's in 2018 uni entries?

# %%
df.query('TP_SEXO == "1"').TP_SEXO.count()
# Out:
# 55693

# %% [markdown]
# ## Racial declaration

# %%
colour = df['TP_COR_RACA'].value_counts()
# print(colour)

pieChart = colour.plot(kind='pie', figsize=(20,10))
# 0. Aluno não quis declarar cor/raça   1. Branca 2. Preta 3. Parda 4. Amarela 5. Indígena 9. Não dispõe da informação (Não resposta)
pieChart.legend(["Branca", "Pardo", "NDA", "Preta", "Amarela", "Indigena", "No info"])

# %% [markdown]
# ## High school type

# %%
middle_school = df['TP_ESCOLA_CONCLUSAO_ENS_MEDIO'].value_counts()
# print(middle_school)

chart = middle_school.plot(kind='pie', figsize=(20,10))
# 1. Pública 2. Privada  
chart.legend(["Pública", "Privada", "No info"])

# %% [markdown]
# ## Courses

# %%
coursedf = pd.read_csv("data/2018_cursos.csv", sep='|')
code_course_sample = coursedf[["CO_CURSO", "NO_CURSO"]]
code_course_sample = code_course_sample.set_index('CO_CURSO')
code_course_sample
# Out:
#                                            NO_CURSO
# CO_CURSO
# 1                                           DIREITO
# 2                               CI�NCIAS ECON�MICAS
# 3                                  ENGENHARIA CIVIL
# 6                                         PEDAGOGIA
# 7                                    SERVI�O SOCIAL
# 8                                CI�NCIAS CONT�BEIS
# 9                                         AGRONOMIA
# 10                             ENGENHARIA FLORESTAL
# 12                                         MEDICINA
# 13                                    ADMINISTRA��O
# 15                                         GEOLOGIA
# 16                              ENGENHARIA EL�TRICA
# 17                                       ENFERMAGEM
# 19                                  EDUCA��O F�SICA
# 20                                         NUTRI��O
# 21                               CI�NCIAS CONT�BEIS
# 23                                        PEDAGOGIA
# ...

# %%
df_fixed_course = df.copy()
df_fixed_course['NO_CURSO'] = pd.Series()

# print(code_course_sample.loc[1386512, 'CO_CURSO'])
# print(code_course_sample.loc[5498, 'NO_CURSO'])
df_fixed_course['NO_CURSO'] = df_fixed_course['CO_CURSO'].apply(
    lambda x: code_course_sample.loc[int(x), 'NO_CURSO']
# df_fixed_course
# Out:
#   File "<ipython-input-30-0da1adfce460>", line 8
#     # df_fixed_course
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
code_course_sample.loc[73557, 'NO_CURSO']
code_course_sample.loc[5498, 'NO_CURSO']
# Out:
# 'DIREITO'

# %%
women_courses = df_fixed_course.query('TP_SEXO == "1"') #.TP_SEXO.count()
final_w_course = women_courses['NO_CURSO'].value_counts()
# print(final_w_course[:15])

# chart = final_w_course[:8].plot(kind='pie', figsize=(20,10))
# chart

# %% [markdown]
# ## Uni type

# %%
uni_type = df['TP_CATEGORIA_ADMINISTRATIVA'].value_counts()
# print(uni_type)

chart = uni_type.plot(kind='pie', figsize=(20,10))
# 1. Pública Federal 2. Pública Estadual 3. Pública Municipal 4. Privada com fins lucrativos 5. Privada sem fins lucrativos 6. Privada - Particular em sentido estrito 7. Especial 8. Privada comunitária 9. Privada confessional|
chart.legend(["Privada com fins lucrativos", "Privada sem fins lucrativos", "Pública Federal", "Pública Estadual", "Pública Municipal", "Especial"])

# %%
type_ = df['TP_MODALIDADE_ENSINO'].value_counts()
print(type_)

type_.plot(kind='bar', figsize=(20,10))
# Out:
# 1    39530
# 2    16163
# Name: TP_MODALIDADE_ENSINO, dtype: int64

# %% [markdown]
# ## Study Type

# %%
study_type = df['TP_MODALIDADE_ENSINO'].value_counts()
# print(middle_school)

chart = study_type.plot(kind='pie', figsize=(20,10))
# 1. Presencial 2. Curso a distância  
chart.legend(["Presencial", "Curso a distância", "No info"])
